# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['adult-test.csv', 'adult-training.csv']

# %%
# no col titles, in normal task that  mast be provide 
train = pd.read_csv("../input/adult-training.csv", header=None)

# %%
train.sample(10)
# Out:
#        0                  1       2    ...    12              13      14
# 28418  32        Federal-gov  402361   ...    40   United-States   <=50K
# 1606   35                  ?  451940   ...    40   United-States   <=50K
# 14026  39            Private  191103   ...    40   United-States   <=50K
# 4236   75   Self-emp-not-inc  231741   ...     3   United-States   <=50K
# 23615  48            Private  159854   ...    40   United-States   <=50K
# 6564   21                  ?  161930   ...    30   United-States   <=50K
# 16364  64            Private  251292   ...    20            Cuba   <=50K
# 5820   37   Self-emp-not-inc  282461   ...    60   United-States   <=50K
# 23895  28            Private  132191   ...    45   United-States    >50K
# 21477  25            Private  305472   ...    48   United-States   <=50K
#
# [10 rows x 15 columns]

# %%
def transform_data_1(df):
    # turn all in numerical
    cat_columns = [1, 3, 5, 6, 7, 8, 9, 13, 14]
    df[cat_columns] = df[cat_columns].astype('category')
    df[cat_columns] = df[cat_columns].apply(lambda x: x.cat.codes)
    scaler = MinMaxScaler()
    df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
    return df

# %%
train = transform_data_1(train)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int8, int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %%
# corelation matrix
corr = train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col0 {
#             background-color:  #b40426;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col1 {
#             background-color:  #5572df;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col2 {
#             background-color:  #3b4cc0;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col3 {
#             background-color:  #4257c9;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col4 {
#             background-color:  #5f7fe8;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col5 {
#             background-color:  #3b4cc0;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col6 {
#             background-color:  #4a63d3;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col7 {
#             background-color:  #7b9ff9;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col8 {
#             background-color:  #6384eb;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col9 {
#             background-color:  #c7d7f0;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col10 {
#             background-color:  #6282ea;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col11 {
#             background-color:  #5d7ce6;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col12 {
#             background-color:  #8fb1fe;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col13 {
#             background-color:  #4961d2;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row0_col14 {
#             background-color:  #bcd2f7;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col0 {
#             background-color:  #80a3fa;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col1 {
#             background-color:  #b40426;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col2 {
#             background-color:  #4b64d5;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col3 {
#             background-color:  #4c66d6;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col4 {
#             background-color:  #6485ec;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col5 {
#             background-color:  #6c8ff1;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col6 {
#             background-color:  #a1c0ff;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col7 {
#             background-color:  #a2c1ff;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col8 {
#             background-color:  #6a8bef;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col9 {
#             background-color:  #c9d7f0;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col10 {
#             background-color:  #5572df;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col11 {
#             background-color:  #4f69d9;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col12 {
#             background-color:  #a2c1ff;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col13 {
#             background-color:  #465ecf;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row1_col14 {
#             background-color:  #89acfd;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col0 {
#             background-color:  #6a8bef;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col1 {
#             background-color:  #4f69d9;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col2 {
#             background-color:  #b40426;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col3 {
#             background-color:  #3d50c3;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col4 {
#             background-color:  #485fd1;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col5 {
#             background-color:  #86a9fc;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col6 {
#             background-color:  #506bda;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col7 {
#             background-color:  #b7cff9;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col8 {
#             background-color:  #5470de;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col9 {
#             background-color:  #bbd1f8;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col10 {
#             background-color:  #4b64d5;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col11 {
#             background-color:  #4961d2;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col12 {
#             background-color:  #7699f6;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col13 {
#             background-color:  #3b4cc0;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row2_col14 {
#             background-color:  #799cf8;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col0 {
#             background-color:  #7b9ff9;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col1 {
#             background-color:  #5a78e4;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col2 {
#             background-color:  #485fd1;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col3 {
#             background-color:  #b40426;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col4 {
#             background-color:  #c5d6f2;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col5 {
#             background-color:  #7597f6;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col6 {
#             background-color:  #4961d2;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col7 {
#             background-color:  #b3cdfb;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col8 {
#             background-color:  #5e7de7;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col9 {
#             background-color:  #afcafc;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col10 {
#             background-color:  #5470de;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col11 {
#             background-color:  #506bda;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col12 {
#             background-color:  #8badfd;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col13 {
#             background-color:  #5d7ce6;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row3_col14 {
#             background-color:  #92b4fe;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col0 {
#             background-color:  #89acfd;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col1 {
#             background-color:  #6384eb;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col2 {
#             background-color:  #4358cb;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col3 {
#             background-color:  #bbd1f8;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col4 {
#             background-color:  #b40426;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col5 {
#             background-color:  #6b8df0;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col6 {
#             background-color:  #7295f4;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col7 {
#             background-color:  #a1c0ff;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col8 {
#             background-color:  #6384eb;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col9 {
#             background-color:  #b9d0f9;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col10 {
#             background-color:  #7093f3;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col11 {
#             background-color:  #6485ec;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col12 {
#             background-color:  #a5c3fe;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col13 {
#             background-color:  #5977e3;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row4_col14 {
#             background-color:  #d4dbe6;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002row5_col0 {
#             background-color:  #3b4cc0;
#         }    #T_03f7d54a_4edd_11e9_8089_0242ac130002ro

# %%
# i will take cols 0, 4, 5, 7, 9, 10, 11, 12
def transform_data_2(df):
    # drop res of colums
    df = df.drop([1,2,3,6,8,13], axis=1)
    return df

# %%
train = transform_data_2(train)
train.sample(5)
# Out:
#              0         4         5    7    9    10   11        12   14
# 18175  0.534247  0.533333  0.333333  0.0  1.0  0.0  0.0  0.397959  0.0
# 27989  0.260274  0.666667  0.833333  0.6  0.0  0.0  0.0  0.397959  0.0
# 624    0.410959  0.266667  0.500000  0.8  1.0  0.0  0.0  0.397959  0.0
# 25159  0.178082  0.200000  0.833333  0.2  1.0  0.0  0.0  0.346939  0.0
# 30752  0.315068  0.733333  0.333333  0.0  1.0  0.0  0.0  0.438776  0.0

# %%
# chcek for nan values
train.isnull().any().any()
# Out:
# False

# %%
# spliting data
y_train_all = train[14]
train = train.drop(14, axis=1)
x_train, x_test, y_train, y_test = train_test_split(train, y_train_all, test_size=0.2, random_state=42)

# %%
y_test.shape
# Out:
# (6513,)

# %%
# logistic regresion sklearn model
model = LogisticRegression(max_iter = 100, multi_class='ovr', solver='lbfgs')

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           n_jobs=None, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
model.score(x_test, y_test)
# Out:
# 0.8234300629510211
